# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from pprint import pprint

# %%
netflix_kaggle = pd.read_csv("netflix_titles(original).csv")
netflix_kaggle
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
netflix_us = pd.read_csv("netflix.csv") 
netflix_us = netflix_us.drop(columns=['Unnamed: 0'])
netflix_us
# Out:
#              State                               Show
# 0          Alabama                          Riverdale
# 1           Alaska                          Iron Fist
# 2          Arizona       The End of the F***ing World
# 3         Arkansas                          Riverdale
# 4       California                    Jane the Virgin
# 5         Colorado                    Stranger Things
# 6      Connecticut                     13 Reasons Why
# 7         Delaware                          Iron Fist
# 8          Florida                          Daredevil
# 9          Georgia                          Luke Cage
# 10          Hawaii                          Iron Fist
# 11           Idaho                    Stranger Things
# 12        Illinois                     13 Reasons Why
# 13         Indiana                      The Defenders
# 14            Iowa       The End of the F***ing World
# 15          Kansas            Orange Is the New Black
# ...

# %%
netflix_kaggle = netflix_kaggle.rename(columns={'title': 'Show'})
netflix_kaggle
# Out:
#        show_id     type                                         Show  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
state_genre = pd.merge(netflix_us, netflix_kaggle, on='Show')
state_genre
# Out:
#              State                               Show   show_id     type  \
# 0          Alabama                          Riverdale  80133311  TV Show
# 1         Arkansas                          Riverdale  80133311  TV Show
# 2          Arizona       The End of the F***ing World  80175722  TV Show
# 3             Iowa       The End of the F***ing World  80175722  TV Show
# 4            Maine       The End of the F***ing World  80175722  TV Show
# 5           Nevada       The End of the F***ing World  80175722  TV Show
# 6    New Hampshire       The End of the F***ing World  80175722  TV Show
# 7   South Carolina       The End of the F***ing World  80175722  TV Show
# 8         Colorado                    Stranger Things  80057281  TV Show
# 9            Idaho                    Stranger Things  80057281  TV Show
# 10        Nebraska                    Stranger Things  80057281  TV Show
# 11            Utah                    Stranger Things  80057281  TV Show
# ...
