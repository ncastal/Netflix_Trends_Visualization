# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from pprint import pprint

# %%
netflix_us = pd.read_csv("netflix.csv") 
netflix_us = netflix_us.drop(columns=['Unnamed: 0'])
netflix_us
# Out:
#              State                               Show
# 0          Alabama                          Riverdale
# 1           Alaska                          Iron Fist
# 2          Arizona       The End of the F***ing World
# 3         Arkansas                          Riverdale
# 4       California                    Jane the Virgin
# 5         Colorado                    Stranger Things
# 6      Connecticut                     13 Reasons Why
# 7         Delaware                          Iron Fist
# 8          Florida                          Daredevil
# 9          Georgia                          Luke Cage
# 10          Hawaii                          Iron Fist
# 11           Idaho                    Stranger Things
# 12        Illinois                     13 Reasons Why
# 13         Indiana                      The Defenders
# 14            Iowa       The End of the F***ing World
# 15          Kansas            Orange Is the New Black
# ...

# %%
statelatlong = pd.read_csv("statelatlong.csv") 
# statelatlong
# statelatlong = statelatlong.drop(columns=['State'])
statelatlong = statelatlong.rename(columns={"State" : "State_short","City": "State"})
statelatlong
# Out:
#    State_short   Latitude   Longitude                 State
# 0           AL  32.601011  -86.680736               Alabama
# 1           AK  61.302501 -158.775020                Alaska
# 2           AZ  34.168219 -111.930907               Arizona
# 3           AR  34.751928  -92.131378              Arkansas
# 4           CA  37.271875 -119.270415            California
# 5           CO  38.997934 -105.550567              Colorado
# 6           CT  41.518784  -72.757507           Connecticut
# 7           DE  39.145251  -75.418921              Delaware
# 8           DC  38.899349  -77.014567  District of Columbia
# 9           FL  27.975728  -83.833017               Florida
# 10          GA  32.678125  -83.222976               Georgia
# 11          HI  20.460000 -157.505000                Hawaii
# 12          ID  45.494576 -114.142430                 Idaho
# 13          IL  39.739318  -89.504139              Illinois
# 14          IN  39.766219  -86.441277               Indiana
# ...

# %%
# pd.merge(netflix_us, how='outer', on= (statelatlong))
# DataFrame.merge(right, how='inner', on=State, left_on=None, right_on=None)
netflix_statelatlong = pd.merge(netflix_us, statelatlong, on='State')
netflix_statelatlong
# Out:
#              State                               Show State_short   Latitude  \
# 0          Alabama                          Riverdale          AL  32.601011
# 1           Alaska                          Iron Fist          AK  61.302501
# 2          Arizona       The End of the F***ing World          AZ  34.168219
# 3         Arkansas                          Riverdale          AR  34.751928
# 4       California                    Jane the Virgin          CA  37.271875
# 5         Colorado                    Stranger Things          CO  38.997934
# 6      Connecticut                     13 Reasons Why          CT  41.518784
# 7         Delaware                          Iron Fist          DE  39.145251
# 8          Florida                          Daredevil          FL  27.975728
# 9          Georgia                          Luke Cage          GA  32.678125
# 10          Hawaii                          Iron Fist          HI  20.460000
# ...

# %%
netflix_statelatlong.to_csv('netflix_statelatlong.csv')
