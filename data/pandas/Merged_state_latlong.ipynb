# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from pprint import pprint

# %%
netflix_us = pd.read_csv("netflix.csv") 
netflix_us = netflix_us.drop(columns=['Unnamed: 0'])
netflix_us
# Out:
#              State                               Show
# 0          Alabama                          Riverdale
# 1           Alaska                          Iron Fist
# 2          Arizona       The End of the F***ing World
# 3         Arkansas                          Riverdale
# 4       California                    Jane the Virgin
# 5         Colorado                    Stranger Things
# 6      Connecticut                     13 Reasons Why
# 7         Delaware                          Iron Fist
# 8          Florida                          Daredevil
# 9          Georgia                          Luke Cage
# 10          Hawaii                          Iron Fist
# 11           Idaho                    Stranger Things
# 12        Illinois                     13 Reasons Why
# 13         Indiana                      The Defenders
# 14            Iowa       The End of the F***ing World
# 15          Kansas            Orange Is the New Black
# 16        Kentucky                          Daredevil
# 17       Louisiana            Orange Is the New Black
# 18           Maine       The End of the F***ing World
# 19        Maryland                          Luke Cage
# 20   Massachusetts                     Peaky Blinders
# 21        Michigan            Orange Is the New Black
# 22       Minnesota                  Making a Murderer
# 23     Mississippi                     13 Reasons Why
# 24        Missouri                              Ozark
# 25         Montana                               Dark
# 26        Nebraska                    Stranger Things
# 27          Nevada       The End of the F***ing World
# 28   New Hampshire       The End of the F***ing World
# 29      New Jersey                     13 Reasons Why
# 30      New Mexico      Breaking Bad/Better Call Saul
# 31        New York                          Daredevil
# 32  North Carolina                     13 Reasons Why
# 33    North Dakota  Gilmore Girls: A Year in the Life
# 34            Ohio                     13 Reasons Why
# 35        Oklahoma            Orange Is the New Black
# 36          Oregon                     Disenchantment
# 37    Pennsylvania                         Mindhunter
# 38    Rhode Island                     13 Reasons Why
# 39  South Carolina       The End of the F***ing World
# 40    South Dakota                          Daredevil
# 41       Tennessee                     House of Cards
# 42           Texas                    Jane the Virgin
# 43            Utah                    Stranger Things
# 44         Vermont   Comedians in Cars Getting Coffee
# 45        Virginia                          Daredevil
# 46      Washington                     Altered Carbon
# 47              DC                   ***16-way tie***
# 48   West Virginia            Orange Is the New Black
# 49       Wisconsin                  Making a Murderer
# 50         Wyoming                      Lost in Space

# %%
statelatlong = pd.read_csv("latlong.csv") 
statelatlong = statelatlong.drop(columns=['Unnamed: 0'])
statelatlong = statelatlong.rename(columns={"state" : "State_abbrev","name": "State"})
statelatlong
# Out:
#    State_abbrev  latitude  longitude                 State
# 0            AK   63.5888  -154.4931                Alaska
# 1            AL   32.3182   -86.9023               Alabama
# 2            AR   35.2010   -91.8318              Arkansas
# 3            AZ   34.0489  -111.0937               Arizona
# 4            CA   36.7783  -119.4179            California
# 5            CO   39.5501  -105.7821              Colorado
# 6            CT   41.6032   -73.0877           Connecticut
# 7            DC   38.9060   -77.0334  District of Columbia
# 8            DE   38.9108   -75.5277              Delaware
# 9            FL   27.6648   -81.5158               Florida
# 10           GA   32.1574   -82.9071               Georgia
# 11           HI   19.8987  -155.6659                Hawaii
# 12           IA   41.8780   -93.0977                  Iowa
# 13           ID   44.0682  -114.7420                 Idaho
# 14           IL   40.6331   -89.3985              Illinois
# 15           IN   40.5512   -85.6024               Indiana
# 16           KS   39.0119   -98.4842                Kansas
# 17           KY   37.8393   -84.2700              Kentucky
# 18           LA   31.2448   -92.1450             Louisiana
# 19           MA   42.4072   -71.3824         Massachusetts
# 20           MD   39.0458   -76.6413              Maryland
# 21           ME   45.2538   -69.4455                 Maine
# 22           MI   44.3148   -85.6024              Michigan
# 23           MN   46.7296   -94.6859             Minnesota
# 24           MO   37.9643   -91.8318              Missouri
# 25           MS   32.3547   -89.3985           Mississippi
# 26           MT   46.8797  -110.3626               Montana
# 27           NC   35.7596   -79.0193        North Carolina
# 28           ND   47.5515  -101.0020          North Dakota
# 29           NE   41.4925   -99.9018              Nebraska
# 30           NH   43.1939   -71.5724         New Hampshire
# 31           NJ   40.0583   -74.4057            New Jersey
# 32           NM   34.9727  -105.0324            New Mexico
# 33           NV   38.8026  -116.4194                Nevada
# 34           NY   43.2994   -74.2179              New York
# 35           OH   40.4173   -82.9071                  Ohio
# 36           OK   35.0078   -97.0929              Oklahoma
# 37           OR   43.8041  -120.5542                Oregon
# 38           PA   41.2033   -77.1945          Pennsylvania
# 39           PR   18.2208   -66.5901           Puerto Rico
# 40           RI   41.5801   -71.4774          Rhode Island
# 41           SC   33.8361   -81.1637        South Carolina
# 42           SD   43.9695   -99.9018          South Dakota
# 43           TN   35.5175   -86.5804             Tennessee
# 44           TX   31.9686   -99.9018                 Texas
# 45           UT   39.3210  -111.0937                  Utah
# 46           VA   37.4316   -78.6569              Virginia
# 47           VT   44.5588   -72.5778               Vermont
# 48           WA   47.7511  -120.7401            Washington
# 49           WI   43.7844   -88.7879             Wisconsin
# 50           WV   38.5976   -80.4549         West Virginia
# 51           WY   43.0760  -107.2903               Wyoming

# %%
# pd.merge(netflix_us, how='outer', on= (statelatlong))
# DataFrame.merge(right, how='inner', on=State, left_on=None, right_on=None)
netflix_statelatlong = pd.merge(netflix_us, statelatlong, on='State')
netflix_statelatlong
# Out:
#              State                               Show State_abbrev  latitude  \
# 0          Alabama                          Riverdale           AL   32.3182
# 1           Alaska                          Iron Fist           AK   63.5888
# 2          Arizona       The End of the F***ing World           AZ   34.0489
# 3         Arkansas                          Riverdale           AR   35.2010
# 4       California                    Jane the Virgin           CA   36.7783
# 5         Colorado                    Stranger Things           CO   39.5501
# 6      Connecticut                     13 Reasons Why           CT   41.6032
# 7         Delaware                          Iron Fist           DE   38.9108
# 8          Florida                          Daredevil           FL   27.6648
# 9          Georgia                          Luke Cage           GA   32.1574
# 10          Hawaii                          Iron Fist           HI   19.8987
# 11           Idaho                    Stranger Things           ID   44.0682
# 12        Illinois                     13 Reasons Why           IL   40.6331
# 13         Indiana                      The Defenders           IN   40.5512
# 14            Iowa       The End of the F***ing World           IA   41.8780
# 15          Kansas            Orange Is the New Black           KS   39.0119
# 16        Kentucky                          Daredevil           KY   37.8393
# 17       Louisiana            Orange Is the New Black           LA   31.2448
# 18           Maine       The End of the F***ing World           ME   45.2538
# 19        Maryland                          Luke Cage           MD   39.0458
# 20   Massachusetts                     Peaky Blinders           MA   42.4072
# 21        Michigan            Orange Is the New Black           MI   44.3148
# 22       Minnesota                  Making a Murderer           MN   46.7296
# 23     Mississippi                     13 Reasons Why           MS   32.3547
# 24        Missouri                              Ozark           MO   37.9643
# 25         Montana                               Dark           MT   46.8797
# 26        Nebraska                    Stranger Things           NE   41.4925
# 27          Nevada       The End of the F***ing World           NV   38.8026
# 28   New Hampshire       The End of the F***ing World           NH   43.1939
# 29      New Jersey                     13 Reasons Why           NJ   40.0583
# 30      New Mexico      Breaking Bad/Better Call Saul           NM   34.9727
# 31        New York                          Daredevil           NY   43.2994
# 32  North Carolina                     13 Reasons Why           NC   35.7596
# 33    North Dakota  Gilmore Girls: A Year in the Life           ND   47.5515
# 34            Ohio                     13 Reasons Why           OH   40.4173
# 35        Oklahoma            Orange Is the New Black           OK   35.0078
# 36          Oregon                     Disenchantment           OR   43.8041
# 37    Pennsylvania                         Mindhunter           PA   41.2033
# 38    Rhode Island                     13 Reasons Why           RI   41.5801
# 39  South Carolina       The End of the F***ing World           SC   33.8361
# 40    South Dakota                          Daredevil           SD   43.9695
# 41       Tennessee                     House of Cards           TN   35.5175
# 42           Texas                    Jane the Virgin           TX   31.9686
# 43            Utah                    Stranger Things           UT   39.3210
# 44         Vermont   Comedians in Cars Getting Coffee           VT   44.5588
# 45        Virginia                          Daredevil           VA   37.4316
# 46      Washington                     Altered Carbon           WA   47.7511
# 47   West Virginia            Orange Is the New Black           WV   38.5976
# 48       Wisconsin                  Making a Murderer           WI   43.7844
# 49         Wyoming                      Lost in Space           WY   43.0760
#
#     longitude
# 0    -86.9023
# 1   -154.4931
# 2   -111.0937
# 3    -91.8318
# 4   -119.4179
# 5   -105.7821
# 6    -73.0877
# 7    -75.5277
# 8    -81.5158
# 9    -82.9071
# 10  -155.6659
# 11  -114.7420
# 12   -89.3985
# 13   -85.6024
# 14   -93.0977
# 15   -98.4842
# 16   -84.2700
# 17   -92.1450
# 18   -69.4455
# 19   -76.6413
# 20   -71.3824
# 21   -85.6024
# 22   -94.6859
# 23   -89.3985
# 24   -91.8318
# 25  -110.3626
# 26   -99.9018
# 27  -116.4194
# 28   -71.5724
# 29   -74.4057
# 30  -105.0324
# 31   -74.2179
# 32   -79.0193
# 33  -101.0020
# 34   -82.9071
# 35   -97.0929
# 36  -120.5542
# 37   -77.1945
# 38   -71.4774
# 39   -81.1637
# 40   -99.9018
# 41   -86.5804
# 42   -99.9018
# 43  -111.0937
# 44   -72.5778
# 45   -78.6569
# 46  -120.7401
# 47   -80.4549
# 48   -88.7879
# 49  -107.2903

# %%
netflix_statelatlong.to_csv('netflix_statelatlong.csv')
